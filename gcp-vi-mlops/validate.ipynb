# %%
import sys
print(sys.executable)

# %%
# %%bash
#
# ls -lash
# pwd
# type -a python
# type -a pip
# pip list -v

# %%
# %%bash
#
# python -m pip list -v

# %%
# %pip list -v

# %%
# %conda list

# %%
# %%bash
# source /opt/homebrew/anaconda3/etc/profile.d/conda.sh
# conda activate training-data-analyst
# pip list -v
